# %% [markdown]
# ### Step 1: Importing Necessary Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from torchvision.transforms import ToTensor

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2: Loading the Fashion-MNIST Data

# %%
train_data = datasets.FashionMNIST(root = '../Data', train = True, download = True, transform = ToTensor())
test_data = datasets.FashionMNIST(root = '../Data', train = False, download = True, transform = ToTensor())

# %%
train_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: ../Data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: ../Data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
train_data[0]
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %%
image, label = train_data[0]
print('Shape:', image.shape, '\nLabel:', label)
# Out:
# Shape: torch.Size([1, 28, 28])
# Label: 9

# %% [markdown]
# ### Step 3: Loading Batches With Dataloader

# %%
torch.manual_seed(100)

train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %% [markdown]
# ### Step 4: Defining the Strings for Labels

# %%
class_names = ['T-shirt','Trouser','Sweater','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Boot']

# %% [markdown]
# ### Step 5: Viewing the Dataset

# %%
plt.imshow(train_data[0][0].squeeze(), cmap='gray')

# %%
# CODE HERE
np.set_printoptions(formatter=dict(int=lambda x: f'{x:5}')) # to widen the printed array

# Grab the first batch of 10 images
for images,labels in train_loader: 
    break

# Print the labels
print('Label:', labels.numpy())
print('Class: ', *np.array([class_names[i] for i in labels]))

# Print the images
im = make_grid(images, nrow=10)  # the default nrow is 8
plt.figure(figsize=(10,4))
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# Label: [    5     9     1     0     6     0     2     8     7     7]
# Class:  Sandal Boot Trouser T-shirt Shirt T-shirt Sweater Bag Sneaker Sneaker

# %% [markdown]
# ### Step 6: Defining the Convolutional Neural Network Class

# %%
class ConvolutionalNeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        # Defining the convolutional layers
        self.conv1 = nn.Conv2d(1, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)

        # Defining the linear layers 
        self.fc1 = nn.Linear(5*5*16, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64,10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)

        X = self.flatten(X)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)

        return F.log_softmax(X, dim=1)

# %%
torch.manual_seed(100)

model = ConvolutionalNeuralNetwork()
model
# Out:
# ConvolutionalNeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ### Step 7: Count the Model Parameters

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')

# %%
count_parameters(model)
# Out:
#     54
#      6
#    864
#     16
#  51200
#    128
#   8192
#     64
#    640
#     10
# ______
#  61174

# %% [markdown]
# ### Step 8: Defining the Loss Function and the Optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# %% [markdown]
# ### Step 9: Training the Model

# %%
import time 

start_time = time.time()

epochs = 10
train_correct = []
train_losses = []
test_correct = []
test_losses = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    for b, (X_train, y_train) in enumerate(train_loader):
        b +=1
        # Training the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)

        # Tallying the number of correct predictions
        predicted = torch.max(y_pred.detach(), 1)[1]
        trn_corr += (predicted == y_train).sum()

        # Updating the parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%1000 == 0:
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/50000]  loss: {loss.item():10.8f}  \
            accuracy: {trn_corr.item()*100/(10*b):7.3f}%')

    # Updating the lists for losses and the number of correct predictions
    train_correct.append(trn_corr.item())
    train_losses.append(loss.item())

    # Now for the testing batches
    with torch.inference_mode():
        for b, (X_test, y_test) in enumerate(test_loader):
            y_val = model(X_test)
            predicted = torch.max(y_val.detach(), 1)[1]
            tst_corr += (predicted == y_test).sum()

        loss = criterion(y_val, y_test)
        test_correct.append(tst_corr.item())
        test_losses.append(loss.item())

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch: 1000 [ 10000/50000]  loss: 0.47147971              accuracy:  69.230%
# epoch:  0  batch: 2000 [ 20000/50000]  loss: 0.86292374              accuracy:  73.945%
# epoch:  0  batch: 3000 [ 30000/50000]  loss: 0.68478781              accuracy:  76.080%
# epoch:  0  batch: 4000 [ 40000/50000]  loss: 0.38703743              accuracy:  77.793%
# epoch:  0  batch: 5000 [ 50000/50000]  loss: 0.34738940              accuracy:  79.078%
# epoch:  0  batch: 6000 [ 60000/50000]  loss: 0.61910611              accuracy:  80.072%
# epoch:  1  batch: 1000 [ 10000/50000]  loss: 0.10085209              accuracy:  86.660%
# epoch:  1  batch: 2000 [ 20000/50000]  loss: 0.13553783              accuracy:  86.560%
# epoch:  1  batch: 3000 [ 30000/50000]  loss: 0.10280997              accuracy:  86.707%
# epoch:  1  batch: 4000 [ 40000/50000]  loss: 0.21403560              accuracy:  86.838%
# epoch:  1  batch: 5000 [ 50000/50000]  loss: 0.02585355              accuracy:  86.866%
# epoch:  1  batch: 6000 [ 60000/50000]  loss: 0.17125955              accuracy:  87.057%
# epoch:  2  batch: 1000 [ 10000/50000]  loss: 0.26476425              accuracy:  87.850%
# epoch:  2  batch: 2000 [ 20000/50000]  loss: 0.39229575              accuracy:  88.440%
# epoch:  2  batch: 3000 [ 30000/50000]  loss: 0.53418887              accuracy:  88.300%
# epoch:  2  batch: 4000 [ 40000/50000]  loss: 0.04492166              accuracy:  88.368%
# epoch:  2  batch: 5000 [ 50000/50000]  loss: 0.10497862              accuracy:  88.442%
# epoch:  2  batch: 6000 [ 60000/50000]  loss: 0.18047212              accuracy:  88.497%
# epoch:  3  batch: 1000 [ 10000/50000]  loss: 0.35452110              accuracy:  89.160%
# epoch:  3  batch: 2000 [ 20000/50000]  loss: 0.40399131              accuracy:  89.170%
# epoch:  3  batch: 3000 [ 30000/50000]  loss: 0.50165886              accuracy:  89.263%
# epoch:  3  batch: 4000 [ 40000/50000]  loss: 0.09320420              accuracy:  89.343%
# epoch:  3  batch: 5000 [ 50000/50000]  loss: 0.43990570              accuracy:  89.402%
# epoch:  3  batch: 6000 [ 60000/50000]  loss: 0.35482532              accuracy:  89.418%
# epoch:  4  batch: 1000 [ 10000/50000]  loss: 0.37107044              accuracy:  90.540%
# epoch:  4  batch: 2000 [ 20000/50000]  loss: 0.38143095              accuracy:  90.440%
# epoch:  4  batch: 3000 [ 30000/50000]  loss: 0.26892713              accuracy:  90.237%
# epoch:  4  batch: 4000 [ 40000/50000]  loss: 0.17777811              accuracy:  90.235%
# epoch:  4  batch: 5000 [ 50000/50000]  loss: 0.12138648              accuracy:  90.170%
# epoch:  4  batch: 6000 [ 60000/50000]  loss: 0.00155399              accuracy:  90.160%
# epoch:  5  batch: 1000 [ 10000/50000]  loss: 0.31961536              accuracy:  90.950%
# epoch:  5  batch: 2000 [ 20000/50000]  loss: 0.21103573              accuracy:  90.885%
# epoch:  5  batch: 3000 [ 30000/50000]  loss: 0.38996705              accuracy:  90.943%
# epoch:  5  batch: 4000 [ 40000/50000]  loss: 0.09605444              accuracy:  90.860%
# epoch:  5  batch: 5000 [ 50000/50000]  loss: 0.21884577              accuracy:  90.878%
# epoch:  5  batch: 6000 [ 60000/50000]  loss: 0.10209551              accuracy:  90.852%
# epoch:  6  batch: 1000 [ 10000/50000]  loss: 0.06954740              accuracy:  91.510%
# epoch:  6  batch: 2000 [ 20000/50000]  loss: 0.38607016              accuracy:  91.425%
# epoch:  6  batch: 3000 [ 30000/50000]  loss: 1.23374915              accuracy:  91.510%
# epoch:  6  batch: 4000 [ 40000/50000]  loss: 0.50606906              accuracy:  91.410%
# epoch:  6  batch: 5000 [ 50000/50000]  loss: 0.15568060              accuracy:  91.396%
# epoch:  6  batch: 6000 [ 60000/50000]  loss: 0.03204358              accuracy:  91.367%
# epoch:  7  batch: 1000 [ 10000/50000]  loss: 0.11789167              accuracy:  91.720%
# epoch:  7  batch: 2000 [ 20000/50000]  loss: 0.03571437              accuracy:  91.750%
# epoch:  7  batch: 3000 [ 30000/50000]  loss: 0.00795090              accuracy:  91.737%
# epoch:  7  batch: 4000 [ 40000/50000]  loss: 0.31129462              accuracy:  91.728%
# epoch:  7  batch: 5000 [ 50000/50000]  loss: 1.14320540              accuracy:  91.784%
# epoch:  7  batch: 6000 [ 60000/50000]  loss: 0.17687930              accuracy:  91.827%
# epoch:  8  batch: 1000 [ 10000/50000]  loss: 0.19244269              accuracy:  92.750%
# epoch:  8  batch: 2000 [ 20000/50000]  loss: 0.09015284              accuracy:  92.445%
# epoch:  8  batch: 3000 [ 30000/50000]  loss: 0.14058581              accuracy:  92.357%
# epoch:  8  batch: 4000 [ 40000/50000]  loss: 0.09025395              accuracy:  92.302%
# epoch:  8  batch: 5000 [ 50000/50000]  loss: 0.03592302              accuracy:  92.202%
# epoch:  8  batch: 6000 [ 60000/50000]  loss: 0.07369967              accuracy:  92.222%
# epoch:  9  batch: 1000 [ 10000/50000]  loss: 0.03212456              accuracy:  92.900%
# epoch:  9  batch: 2000 [ 20000/50000]  loss: 0.09267806              accuracy:  92.460%
# epoch:  9  batch: 3000 [ 30000/50000]  loss: 0.03947031              accuracy:  92.443%
# epoch:  9  batch: 4000 [ 40000/50000]  loss: 0.51363796              accuracy:  92.370%
# epoch:  9  batch: 5000 [ 50000/50000]  loss: 0.01315247              accuracy:  92.358%
# epoch:  9  batch: 6000 [ 60000/50000]  loss: 0.08667727              accuracy:  92.418%
#
# Duration: 116 seconds

# %% [markdown]
# ### Step 10: Saving the Model

# %%
torch.save(model.state_dict(), 'Fashion-MNIST-CNN-Model.pt')

# %% [markdown]
# ### Step 11: Plotting the Loss and Accuracy Comparions

# %%
plt.plot(train_losses, label='training loss')
plt.plot(test_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();

# %%
plt.plot([t/600 for t in train_correct], label='training accuracy')
plt.plot([t/100 for t in test_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %% [markdown]
# ### Step 12: Evaluating Test Data

# %%
print(test_correct) # contains the results of all 10 epochs
print()
print(f'Test accuracy: {test_correct[-1]*100/10000:.3f}%') # print the most recent result as a percent
# Out:
# [8489, 8718, 8782, 8908, 8856, 8925, 8955, 8951, 8934, 8937]
#
# Test accuracy: 89.370%

# %%
test_all = DataLoader(test_data, batch_size=10000,shuffle=False)

# %%
with torch.inference_mode():
    model.eval()
    correct = 0
    for X_test, y_test in test_all:
        y_val = model(X_test)
        predicted = torch.max(y_val.detach(), 1)[1]
        correct += (predicted == y_test).sum()
print(f'Test accuracy: {correct.item()}/{len(test_data)} = {correct.item()*100/(len(test_data)):7.3f}%')
# Out:
# Test accuracy: 8937/10000 =  89.370%

# %% [markdown]
# ### Step 13: Evaluating the Confusion Matrix

# %%
import seaborn as sn
arr = confusion_matrix(y_test.view(-1), predicted.view(-1))
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();

# %% [markdown]
# ### tep 14: Examining the Misses

# %%
misses = np.array([])
for i in range(len(predicted.view(-1))):
    if predicted[i] != y_test[i]:
        misses = np.append(misses,i).astype('int64')
        
# Display the number of misses
len(misses)
# Out:
# 1063

# %%
# Display the first 8 index positions
misses[:8]
# Out:
# array([   23,    25,    29,    42,    49,    66,    67,    68])

# %%
# Set up an iterator to feed batched rows
r = 8   # row size
row = iter(np.array_split(misses,len(misses)//r+1))

# %%
np.set_printoptions(formatter=dict(int=lambda x: f'{x:5}')) # to widen the printed array

nextrow = next(row)
lbls = y_test.index_select(0,torch.tensor(nextrow)).numpy()
gues = predicted.index_select(0,torch.tensor(nextrow)).numpy()
print("Index:", nextrow)
print("Label:", lbls)
print("Class: ", *np.array([class_names[i] for i in lbls]))
print()
print("Guess:", gues)
print("Class: ", *np.array([class_names[i] for i in gues]))

images = X_test.index_select(0,torch.tensor(nextrow))
im = make_grid(images, nrow=r)
plt.figure(figsize=(8,4))
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# Index: [   23    25    29    42    49    66    67    68]
# Label: [    9     4     3     3     2     2     3     9]
# Class:  Boot Coat Dress Dress Sweater Sweater Dress Boot
#
# Guess: [    5     6     4     8     6     3     4     7]
# Class:  Sandal Shirt Coat Bag Shirt Dress Coat Sneaker

# %% [markdown]
# ### Step 15: Loading the Saved Model

# %%
model2 = ConvolutionalNeuralNetwork()
model2.load_state_dict(torch.load('Fashion-MNIST-CNN-Model.pt'))
model2.eval()
# Out:
# /var/folders/sc/k6080_9j4cx42wf_vh5ybvmw0000gn/T/ipykernel_51060/2604017220.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model2.load_state_dict(torch.load('Fashion-MNIST-CNN-Model.pt'))
# ConvolutionalNeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
test_load_all = DataLoader(test_data, batch_size=10000, shuffle=False)

# %%
with torch.inference_mode():
    correct = 0
    model.eval()
    for X_test, y_test in test_load_all:
        y_val = model2(X_test)
        predicted = torch.max(y_val.detach(), 1)[1]
        correct += (predicted == y_test).sum()
print(f'Test accuracy: {correct.item()}/{len(test_data)} = {correct.item()*100/(len(test_data)):7.3f}%')
# Out:
# Test accuracy: 8937/10000 =  89.370%
